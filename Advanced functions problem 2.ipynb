# %%
def innermost(data): #create the function with name
   
    if not isinstance(data[-1], list): 
        return [x + 1 for x in data]

    # 
    return innermost(data[-1]) 
list = [1,2,3,4,[5,6,7,[8,9]]] #create list
print(innermost(list)) #call function with list
# Out:
# [9, 10]
