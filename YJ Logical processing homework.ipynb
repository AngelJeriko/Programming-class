# Given the array influenza_genome, write code that uses for loops and if statements to do the following and print the results(see below for instructions):

# 1.1 add 1 to the value at the index 300.
print(influenza_genome[300]) #check the number at position 300
for a in range(len(influenza_genome)): #loop through the array, using len to number each position
    if a == 300: #find position 300 in the array
        influenza_genome[a] += 1 #add 1 to that value
print("1.1 new value at position 300:", influenza_genome[300])

# 1.2 for the first 30 elements, if the value of the element is divisable by 3, multiply the value by 3.
for b in range(30): #creates an index with each position numbered
    if isinstance(influenza_genome[b], int) and influenza_genome[b] % 3 ==0: #checks each place in array (influena_genome) to see if it is an integer and divisible by 3 if so proceed to next line
        influenza_genome[b] *= 3 #if the if statement is true, multiply number by 3
print("1.2 new values for the first 30 positions:", influenza_genome[:30]) #print array
# 1.3 for the last 30 elements, if the index value at that point is divisable by 5, replace the value with "a".
for c in range(-30, 0): #creates an index for the last 30 places of the array
    if isinstance(influenza_genome[c], int) and influenza_genome[c] % 5 ==0: #checks each place in array (influena_genome) to see if it is an integer and divisible by 5 if so proceed to next line
        influenza_genome[c] = "a" #if the if statement is true, replace with a string of the letter a
print("1.3 new values for last 30 positions:", influenza_genome[-30:]) #print last 30 of the array
# 1.4 for all elements between index 200 and 300, if the value of the element is divisable by BOTH 3 AND 5, replace the value with the 10.
for d in range(200, 301): #searches the array for positions 200-300
    if isinstance(influenza_genome[d], int) and influenza_genome[d] % 5 ==0 and influenza_genome[d] % 3 ==0: #checks each place in array (influena_genome) to see if it is an integer and divisible by 5 and 3 if so proceed to next line
        influenza_genome[d] = 10 #if the if statement is true, replace with 10
print("1.4 new values at the positions between 200 and 300:", influenza_genome[200:301])
# Only print the section of the array that is modified after completing each operation. i.e only print index 300 of the array after 1.1 and only the first 30 elements after 1.2





# Problem 2 Loops within loops
# Given the array influenza_genome, write code using both for and while loops that:

# 2.1 Create a for loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)

for e in range(234, 238): #set up the for loop for index 234-237
    print(f"Index {e}: {influenza_genome[e]}") #print the value at position 234-237
# 2.2 Create a while loop that iterates over items index 234 through 237 and prints each value (ie there should be 4 items)
f = 234 #creating a varible to step-wise process the the while loop
while f <= 237: #creating the while loop at the indicated value so the desired index items are hit and will stop the loop at the right index value
    print(f"Index while: {f}: {influenza_genome[f]}") #printing the values at the indexed positions
    f += 1 #modifying the variable so the loop will continue to the next value
# 2.3 Create a for loop that iterates over items index 234 through 237 and if the index is 236 print the item 7 times.
for g in range(234, 238): #setting up the for loop for the desired range
    if g == 236: #creating an if statement to target the index value that we want repeated
        x = 6
        while x >= 0:
            print(f"Index 2.3 {g}: {influenza_genome[g]}")
            x -= 1
    else: print(f"Index 2.3 {g}: {influenza_genome[g]}")
        




# Problem 3 Functions
# You are going to implement 3 funtions that will process the influenza_genome list in various ways.
# 3.1 write a function, that takes in the array as an argument, and outputs 10 values from the dataset, spaced out by indexes that are 25 apart (ie 0, 25, 50, etc)
def data_spaces(data): #setting up the name of the function
    return [data[i] for i in range(0,250,25)] #setting up what the functions does, telling it to return 10 numbers with the 25th number from a list
print(f"printed 10 numbers are from the list but all 25 spaces apart {data_spaces(influenza_genome)}") #printing the function which has been applied to the desired list

# 3.2 write a function that takes in the dataset as an argument and outputs 20 values from the dataset, spaced out by indexes that are y apart (ie you can decide how far apart they should be iterated as long as they dont exceed the length of the dataset)
def player_decides(data): #defines the function name
    y = int(input("enter the number that will space out the returned numbers from the list")) #defines the variable y which will be used in the fuction as an input from user
    return [data[i] for i in range(0,y*20,y)] #returns from the list numbers that are spaced by y and reports 20 numbers
results = (player_decides(influenza_genome))
print(results)
 #print to call function and explain
# 3.3 write a function that takes the output from the function from 3.2 as an argument, then only prints out every other item (ie there should only be 10 outputs)
def every_other(values):
    return [values[i] for i in range(0, len(values), 2)]
print(f"printed 10 numbers are from the list but all are spaced based on inputted spaces apart {every_other(results)}")



# # Problem 4 Putting it all together
# # Write a function that implements the code from problem 1.4, then implements the code from problem 2.3.
def problem4(arr):
    data = arr[:]  # work on a copy so the original isn’t mutated
    # ---- Part 1.4: replace values between 200..300 divisible by 3 AND 5 with 10
    for d in range(200, 301):
        if isinstance(data[d], int) and (data[d] % 15 == 0):
            data[d] = 10
    print("1.4 new values at the positions between 200 and 300:", data[200:301])

    # ---- Part 2.3: print 234..237, with index 236 printed 7 extra times (total 8)
    for g in range(234, 238):
        if g == 236:
            x = 6
            while x >= 0:
                print(f"Index 2.3 {g}: {data[g]}")
                x -= 1
        else:
            print(f"Index 2.3 {g}: {data[g]}")
    return data 
print(problem4(influenza_genome))
# The function should create a modified version of the influenza_genome list as per 1.4, then print the section described in problem 2.3.
# Out:
# 7
# 1.1 new value at position 300: 8
# 1.2 new values for the first 30 positions: [19, 45, 7, 27, 36, 18, 17, 20, 29, 14, 22, 8, 45, 36, 63, 25, 11, 10, 90, 4, 18, 72, 54, 63, 28, 22, 13, 19, 4, 23]
# 1.3 new values for last 30 positions: ['a', 'a', 23, 29, 'a', 'a', 'a', 13, 2, 11, 'a', 9, 2, 'a', 27, 14, 11, 'a', 19, 1, 12, 'a', 8, 6, 16, 3, 'a', 'a', 'a', 24]
# 1.4 new values at the positions between 200 and 300: [21, 26, 25, 1, 24, 10, 27, 8, 23, 4, 10, 22, 1, 3, 7, 16, 18, 29, 11, 4, 1, 29, 10, 16, 10, 10, 2, 26, 26, 7, 10, 10, 6, 25, 4, 7, 12, 24, 5, 8, 23, 16, 8, 3, 16, 1, 9, 4, 27, 26, 9, 25, 7, 14, 27, 21, 27, 28, 2, 2, 27, 22, 3, 23, 14, 16, 10, 12, 14, 8, 10, 5, 16, 12, 24, 3, 28, 9, 21, 7, 25, 9, 5, 3, 27, 7, 29, 25, 13, 11, 25, 21, 2, 14, 8, 17, 18, 23, 22, 12, 8]
# Index 234: 4
# Index 235: 7
# Index 236: 12
# Index 237: 24
# Index while: 234: 4
# Index while: 235: 7
# Index while: 236: 12
# Index while: 237: 24
# Index 2.3 234: 4
# Index 2.3 235: 7
# Index 2.3 236: 12
# ...
